# %%
#https://youtube.com/watch?v=qhRNvCVVJaA
#https://www.youtube.com/watch?v=mo96Nqlo1L8
#https://www.youtube.com/watch?v=HGeI30uATws
#https://www.datamachinist.com/reinforcement-learning/part-6-q-learning-for-continuous-state-problems/
import gym 
import math
import numpy as np
from sklearn.preprocessing import KBinsDiscretizer


class QLearnCartPoleSolver():
    def __init__(self, env, buckets=(6, 12), episodes=100, epsilon_decay_rate = 0.1, 
        decay=24, max_steps=100, batch_size = 64, min_lr=0.1, discount=1.0,min_epsilon=0.1):

        self.env = env
        self.action_size = self.env.action_space.n
        self.discount=discount
        self.buckets = buckets
        self.min_lr = min_lr
        self.min_epsilon = min_epsilon 
        self.episodes = episodes
        self.decay = decay
        self.epsilon_decay_rate = epsilon_decay_rate
        self.max_steps = max_steps
        self.batch_size = batch_size
        self.Q_Values = np.zeros(self.buckets +( self.action_size,))
        self.upper_bounds = [
            self.env.observation_space.high[2], math.radians(50)]
        self.lower_bounds = [
            self.env.observation_space.low[2], -math.radians(50)]


    def get_epsilon(self, t):
        return max(self.min_epsilon, min(1., 1. - math.log10((t + 1) / self.decay)))

    def get_learning_rate(self, t):
        return max(self.min_lr, min(1., 1. - math.log10((t + 1) / self.decay)))

    def action(self, state):
        return self.env.action_space.sample() if np.random.random() <= self.epsilon else np.argmax(self.Q_Values[state])

    def updated_q_value(self, state, action, reward, new_state):
        return (self.learning_rate * (reward + self.discount * np.max(self.Q_Values[new_state]) - self.Q_Values[state][action]))

    def discretize_state(self, state):
        _, _, angle, angle_velocity = state
        est = KBinsDiscretizer(n_bins=self.buckets,
                               encode='ordinal', strategy='uniform')
        est.fit([self.lower_bounds, self.upper_bounds])
        return tuple(map(int, est.transform([[angle, angle_velocity]])[0]))
    
    def train(self):
        scores = []
        for episode in range(self.episodes):
            self.learning_rate = self.get_learning_rate(episode)
            self.epsilon = self.get_epsilon(episode)
            state = self.discretize_state(self.env.reset())
            done = False
            reward_current_ep = 0
            step = 1
            while not done:
                # self.env.render()
                action = self.action(state)
                next_state, reward, done, _ = self.env.step(action) 
                next_state = self.discretize_state(next_state)
                self.Q_Values[state][action] += self.updated_q_value(state, action, reward, next_state)
                state = next_state
                reward_current_ep += reward
                # print(f"Trainingsession {episode+1}:", step, "steps")
                step +=1
            scores.append(reward_current_ep)
            print(f"{scores[episode]}  score for ep {episode+1}")
        print('Finished training!')
        #self.env.close()
            
    def run(self):
        done = False
        current_state = self.discretize_state(self.env.reset())
        score = 0
        while not done:
            self.env.render()
            action = self.action(current_state)
            observation, reward, done, _ = self.env.step(action)
            new_state = self.discretize_state(observation)
            current_state = new_state
            score += reward
        print(f"score {score}")
        self.env.close()

env = gym.make('CartPole-v0')

model = QLearnCartPoleSolver(env, episodes=500)
model.train()
# Out:
# 25.0  score for ep 1
# 12.0  score for ep 2
# 15.0  score for ep 3
# 19.0  score for ep 4
# 22.0  score for ep 5
# 10.0  score for ep 6
# 15.0  score for ep 7
# 21.0  score for ep 8
# 20.0  score for ep 9
# 16.0  score for ep 10
# 26.0  score for ep 11
# 19.0  score for ep 12
# 18.0  score for ep 13
# 26.0  score for ep 14
# 18.0  score for ep 15
# 11.0  score for ep 16
# 32.0  score for ep 17
# 23.0  score for ep 18
# 23.0  score for ep 19
# 25.0  score for ep 20
# 25.0  score for ep 21
# 36.0  score for ep 22
# 32.0  score for ep 23
# 16.0  score for ep 24
# 19.0  score for ep 25
# 38.0  score for ep 26
# 10.0  score for ep 27
# 19.0  score for ep 28
# 9.0  score for ep 29
# 18.0  score for ep 30
# 12.0  score for ep 31
# 24.0  score for ep 32
# 12.0  score for ep 33
# 27.0  score for ep 34
# 23.0  score for ep 35
# 21.0  score for ep 36
# 15.0  score for ep 37
# 29.0  score for ep 38
# 22.0  score for ep 39
# 32.0  score for ep 40
# 15.0  score for ep 41
# 17.0  score for ep 42
# 25.0  score for ep 43
# 18.0  score for ep 44
# 21.0  score for ep 45
# 96.0  score for ep 46
# 26.0  score for ep 47
# 39.0  score for ep 48
# 30.0  score for ep 49
# 49.0  score for ep 50
# 48.0  score for ep 51
# 15.0  score for ep 52
# 9.0  score for ep 53
# 20.0  score for ep 54
# 17.0  score for ep 55
# 42.0  score for ep 56
# 21.0  score for ep 57
# 37.0  score for ep 58
# 30.0  score for ep 59
# 17.0  score for ep 60
# 22.0  score for ep 61
# 27.0  score for ep 62
# 20.0  score for ep 63
# 18.0  score for ep 64
# 23.0  score for ep 65
# 13.0  score for ep 66
# 17.0  score for ep 67
# 13.0  score for ep 68
# 23.0  score for ep 69
# 8.0  score for ep 70
# 9.0  score for ep 71
# 10.0  score for ep 72
# 19.0  score for ep 73
# 42.0  score for ep 74
# 14.0  score for ep 75
# 19.0  score for ep 76
# 17.0  score for ep 77
# 11.0  score for ep 78
# 15.0  score for ep 79
# 15.0  score for ep 80
# 20.0  score for ep 81
# 34.0  score for ep 82
# 20.0  score for ep 83
# 10.0  score for ep 84
# 25.0  score for ep 85
# 35.0  score for ep 86
# 15.0  score for ep 87
# 21.0  score for ep 88
# 135.0  score for ep 89
# 55.0  score for ep 90
# 73.0  score for ep 91
# 24.0  score for ep 92
# 18.0  score for ep 93
# 16.0  score for ep 94
# 30.0  score for ep 95
# 64.0  score for ep 96
# 28.0  score for ep 97
# 52.0  score for ep 98
# 38.0  score for ep 99
# 43.0  score for ep 100
# 17.0  score for ep 101
# 142.0  score for ep 102
# 130.0  score for ep 103
# 36.0  score for ep 104
# 114.0  score for ep 105
# 130.0  score for ep 106
# 196.0  score for ep 107
# 54.0  score for ep 108
# 53.0  score for ep 109
# 87.0  score for ep 110
# 21.0  score for ep 111
# 22.0  score for ep 112
# 31.0  score for ep 113
# 49.0  score for ep 114
# 170.0  score for ep 115
# 200.0  score for ep 116
# 200.0  score for ep 117
# 200.0  score for ep 118
# 108.0  score for ep 119
# 200.0  score for ep 120
# 29.0  score for ep 121
# 200.0  score for ep 122
# 113.0  score for ep 123
# 200.0  score for ep 124
# 200.0  score for ep 125
# 200.0  score for ep 126
# 200.0  score for ep 127
# 200.0  score for ep 128
# 42.0  score for ep 129
# 101.0  score for ep 130
# 34.0  score for ep 131
# 150.0  score for ep 132
# 115.0  score for ep 133
# 200.0  score for ep 134
# 137.0  score for ep 135
# 75.0  score for ep 136
# 75.0  score for ep 137
# 138.0  score for ep 138
# 190.0  score for ep 139
# 128.0  score for ep 140
# 173.0  score for ep 141
# 67.0  score for ep 142
# 36.0  score for ep 143
# 69.0  score for ep 144
# 94.0  score for ep 145
# 69.0  score for ep 146
# 200.0  score for ep 147
# 200.0  score for ep 148
# 200.0  score for ep 149
# 200.0  score for ep 150
# 200.0  score for ep 151
# 200.0  score for ep 152
# 200.0  score for ep 153
# 200.0  score for ep 154
# 200.0  score for ep 155
# 200.0  score for ep 156
# 200.0  score for ep 157
# 200.0  score for ep 158
# 200.0  score for ep 159
# 200.0  score for ep 160
# 200.0  score for ep 161
# 200.0  score for ep 162
# 200.0  score for ep 163
# 200.0  score for ep 164
# 200.0  score for ep 165
# 200.0  score for ep 166
# 200.0  score for ep 167
# 200.0  score for ep 168
# 200.0  score for ep 169
# 200.0  score for ep 170
# 200.0  score for ep 171
# 200.0  score for ep 172
# 200.0  score for ep 173
# 200.0  score for ep 174
# 200.0  score for ep 175
# 193.0  score for ep 176
# 200.0  score for ep 177
# 200.0  score for ep 178
# 200.0  score for ep 179
# 200.0  score for ep 180
# 200.0  score for ep 181
# 200.0  score for ep 182
# 200.0  score for ep 183
# 200.0  score for ep 184
# 200.0  score for ep 185
# 200.0  score for ep 186
# 200.0  score for ep 187
# 200.0  score for ep 188
# 200.0  score for ep 189
# 200.0  score for ep 190
# 200.0  score for ep 191
# 200.0  score for ep 192
# 200.0  score for ep 193
# 200.0  score for ep 194
# 200.0  score for ep 195
# 200.0  score for ep 196
# 200.0  score for ep 197
# 200.0  score for ep 198
# 200.0  score for ep 199
# 200.0  score for ep 200
# 200.0  score for ep 201
# 200.0  score for ep 202
# 200.0  score for ep 203
# 200.0  score for ep 204
# 200.0  score for ep 205
# 200.0  score for ep 206
# 200.0  score for ep 207
# 200.0  score for ep 208
# 200.0  score for ep 209
# 200.0  score for ep 210
# 200.0  score for ep 211
# 200.0  score for ep 212
# 200.0  score for ep 213
# 200.0  score for ep 214
# 200.0  score for ep 215
# 200.0  score for ep 216
# 200.0  score for ep 217
# 200.0  score for ep 218
# 200.0  score for ep 219
# 200.0  score for ep 220
# 200.0  score for ep 221
# 200.0  score for ep 222
# 200.0  score for ep 223
# 200.0  score for ep 224
# 142.0  score for ep 225
# 200.0  score for ep 226
# 200.0  score for ep 227
# 200.0  score for ep 228
# 200.0  score for ep 229
# 200.0  score for ep 230
# 200.0  score for ep 231
# 200.0  score for ep 232
# 200.0  score for ep 233
# 200.0  score for ep 234
# 200.0  score for ep 235
# 200.0  score for ep 236
# 200.0  score for ep 237
# 200.0  score for ep 238
# 200.0  score for ep 239
# 200.0  score for ep 240
# 200.0  score for ep 241
# 200.0  score for ep 242
# 200.0  score for ep 243
# 200.0  score for ep 244
# 200.0  score for ep 245
# 200.0  score for ep 246
# 200.0  score for ep 247
# 200.0  score for ep 248
# 200.0  score for ep 249
# 200.0  score for ep 250
# 200.0  score for ep 251
# 200.0  score for ep 252
# 200.0  score for ep 253
# 200.0  score for ep 254
# 200.0  score for ep 255
# 200.0  score for ep 256
# 200.0  score for ep 257
# 200.0  score for ep 258
# 200.0  score for ep 259
# 200.0  score for ep 260
# 200.0  score for ep 261
# 200.0  score for ep 262
# 200.0  score for ep 263
# 200.0  score for ep 264
# 200.0  score for ep 265
# 200.0  score for ep 266
# 200.0  score for ep 267
# 200.0  score for ep 268
# 200.0  score for ep 269
# 200.0  score for ep 270
# 200.0  score for ep 271
# 200.0  score for ep 272
# 200.0  score for ep 273
# 200.0  score for ep 274
# 200.0  score for ep 275
# 200.0  score for ep 276
# 200.0  score for ep 277
# 200.0  score for ep 278
# 200.0  score for ep 279
# 200.0  score for ep 280
# 200.0  score for ep 281
# 200.0  score for ep 282
# 200.0  score for ep 283
# 200.0  score for ep 284
# 200.0  score for ep 285
# 200.0  score for ep 286
# 200.0  score for ep 287
# 200.0  score for ep 288
# 200.0  score for ep 289
# 200.0  score for ep 290
# 200.0  score for ep 291
# 200.0  score for ep 292
# 154.0  score for ep 293
# 200.0  score for ep 294
# 200.0  score for ep 295
# 200.0  score for ep 296
# 200.0  score for ep 297
# 200.0  score for ep 298
# 200.0  score for ep 299
# 200.0  score for ep 300
# 200.0  score for ep 301
# 200.0  score for ep 302
# 200.0  score for ep 303
# 200.0  score for ep 304
# 200.0  score for ep 305
# 200.0  score for ep 306
# 200.0  score for ep 307
# 200.0  score for ep 308
# 200.0  score for ep 309
# 200.0  score for ep 310
# 200.0  score for ep 311
# 200.0  score for ep 312
# 200.0  score for ep 313
# 200.0  score for ep 314
# 200.0  score for ep 315
# 200.0  score for ep 316
# 200.0  score for ep 317
# 200.0  score for ep 318
# 200.0  score for ep 319
# 200.0  score for ep 320
# 200.0  score for ep 321
# 200.0  score for ep 322
# 200.0  score for ep 323
# 200.0  score for ep 324
# 200.0  score for ep 325
# 200.0  score for ep 326
# 200.0  score for ep 327
# 200.0  score for ep 328
# 200.0  score for ep 329
# 200.0  score for ep 330
# 200.0  score for ep 331
# 200.0  score for ep 332
# 200.0  score for ep 333
# 200.0  score for ep 334
# 200.0  score for ep 335
# 200.0  score for ep 336
# 200.0  score for ep 337
# 200.0  score for ep 338
# 200.0  score for ep 339
# 200.0  score for ep 340
# 200.0  score for ep 341
# 200.0  score for ep 342
# 200.0  score for ep 343
# 200.0  score for ep 344
# 200.0  score for ep 345
# 200.0  score for ep 346
# 200.0  score for ep 347
# 200.0  score for ep 348
# 200.0  score for ep 349
# 200.0  score for ep 350
# 200.0  score for ep 351
# 200.0  score for ep 352
# 200.0  score for ep 353
# 200.0  score for ep 354
# 200.0  score for ep 355
# 200.0  score for ep 356
# 200.0  score for ep 357
# 200.0  score for ep 358
# 200.0  score for ep 359
# 200.0  score for ep 360
# 200.0  score for ep 361
# 200.0  score for ep 362
# 200.0  score for ep 363
# 200.0  score for ep 364
# 200.0  score for ep 365
# 200.0  score for ep 366
# 200.0  score for ep 367
# 200.0  score for ep 368
# 200.0  score for ep 369
# 200.0  score for ep 370
# 200.0  score for ep 371
# 200.0  score for ep 372
# 200.0  score for ep 373
# 200.0  score for ep 374
# 200.0  score for ep 375
# 200.0  score for ep 376
# 200.0  score for ep 377
# 200.0  score for ep 378
# 200.0  score for ep 379
# 200.0  score for ep 380
# 200.0  score for ep 381
# 200.0  score for ep 382
# 200.0  score for ep 383
# 200.0  score for ep 384
# 200.0  score for ep 385
# 200.0  score for ep 386
# 200.0  score for ep 387
# 200.0  score for ep 388
# 200.0  score for ep 389
# 200.0  score for ep 390
# 200.0  score for ep 391
# 200.0  score for ep 392
# 200.0  score for ep 393
# 200.0  score for ep 394
# 200.0  score for ep 395
# 200.0  score for ep 396
# 200.0  score for ep 397
# 200.0  score for ep 398
# 200.0  score for ep 399
# 200.0  score for ep 400
# 200.0  score for ep 401
# 200.0  score for ep 402
# 200.0  score for ep 403
# 200.0  score for ep 404
# 200.0  score for ep 405
# 200.0  score for ep 406
# 200.0  score for ep 407
# 200.0  score for ep 408
# 200.0  score for ep 409
# 200.0  score for ep 410
# 200.0  score for ep 411
# 200.0  score for ep 412
# 200.0  score for ep 413
# 200.0  score for ep 414
# 200.0  score for ep 415
# 200.0  score for ep 416
# 200.0  score for ep 417
# 200.0  score for ep 418
# 200.0  score for ep 419
# 200.0  score for ep 420
# 200.0  score for ep 421
# 200.0  score for ep 422
# 200.0  score for ep 423
# 200.0  score for ep 424
# 200.0  score for ep 425
# 200.0  score for ep 426
# 200.0  score for ep 427
# 200.0  score for ep 428
# 200.0  score for ep 429
# 200.0  score for ep 430
# 200.0  score for ep 431
# 200.0  score for ep 432
# 200.0  score for ep 433
# 200.0  score for ep 434
# 200.0  score for ep 435
# 200.0  score for ep 436
# 200.0  score for ep 437
# 200.0  score for ep 438
# 200.0  score for ep 439
# 200.0  score for ep 440
# 200.0  score for ep 441
# 200.0  score for ep 442
# 200.0  score for ep 443
# 200.0  score for ep 444
# 200.0  score for ep 445
# 200.0  score for ep 446
# 200.0  score for ep 447
# 200.0  score for ep 448
# 200.0  score for ep 449
# 200.0  score for ep 450
# 200.0  score for ep 451
# 200.0  score for ep 452
# 200.0  score for ep 453
# 200.0  score for ep 454
# 200.0  score for ep 455
# 200.0  score for ep 456
# 200.0  score for ep 457
# 200.0  score for ep 458
# 200.0  score for ep 459
# 200.0  score for ep 460
# 200.0  score for ep 461
# 200.0  score for ep 462
# 200.0  score for ep 463
# 200.0  score for ep 464
# 200.0  score for ep 465
# 200.0  score for ep 466
# 200.0  score for ep 467
# 200.0  score for ep 468
# 200.0  score for ep 469
# 200.0  score for ep 470
# 200.0  score for ep 471
# 200.0  score for ep 472
# 200.0  score for ep 473
# 200.0  score for ep 474
# 200.0  score for ep 475
# 200.0  score for ep 476
# 200.0  score for ep 477
# 200.0  score for ep 478
# 200.0  score for ep 479
# 200.0  score for ep 480
# 200.0  score for ep 481
# 200.0  score for ep 482
# 200.0  score for ep 483
# 200.0  score for ep 484
# 200.0  score for ep 485
# 200.0  score for ep 486
# 200.0  score for ep 487
# 200.0  score for ep 488
# 200.0  score for ep 489
# 200.0  score for ep 490
# 200.0  score for ep 491
# 200.0  score for ep 492
# 200.0  score for ep 493
# 200.0  score for ep 494
# 200.0  score for ep 495
# 200.0  score for ep 496
# 200.0  score for ep 497
# 200.0  score for ep 498
# 200.0  score for ep 499
# 200.0  score for ep 500
# Finished training!

# %%
model.run()
# Out:
# score 200.0
